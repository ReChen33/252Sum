# %% [markdown]
# Pro: save datetime to string but lost .000000 microseconds
#
# Solu: Time_avg = T_since_Epo[i + (chunk_end - i)//2].strftime("%Y-%m-%d %H:%M:%S.%f")

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
