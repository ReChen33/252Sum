# %%
from datetime import datetime, timedelta

t1 = datetime.now()
t2 = datetime(2024, 12, 31, 23, 59, 59)
d = {
    3:3,
    2:5
}
print(d)
d_sorted = dict(sorted(d.items(), key=lambda x: x[1]))

print(dict_sorted)
# Out:
# {3: 3, 2: 5}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       5 d = {
#       6     3:3,
#       7     2:5
#       8 }
#       9 print(d)
# ---> 10 d_sorted = dict(sorted(d.items(), key=lambda x: x[1]))
#      12 print(dict_sorted)
#
# TypeError: 'dict' object is not callable
