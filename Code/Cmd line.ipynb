# %% [markdown]
# ![image.png](attachment:image.png)
#
# $ jobs #show all background jobs
#
# $ kill %1 #kill job 1

# %% [markdown]
# # scp
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # nano
#
# The letter M represents the Alt key.

# %% [markdown]
# # temp as Adminster
#
#
# su barronlab
#
# sudo [cmd]

# %% [markdown]
# # open the tv in back
#
# firefox &
#
# eog filename.jpg &

# %% [markdown]
# ![image.png](attachment:image.png)
#
# # screen -S (name)  #create a new screen session with a name
#
# # screen -X -S <session_id> quit

# %% [markdown]
# # To see all path env
#
# # nano ~/.bashrc

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
