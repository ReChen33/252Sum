# %%
print("Hello, Summer!")
# Out:
# Hello, Summer!

# %%
import numpy as np
# Out:
# Key: key, Value: [1 2 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4     print(f"Key: {sp}, Value: {mr}")
#       5     assert np.all((mr) >= 0)
# ----> 7 np.array()
#
# TypeError: array() missing required argument 'object' (pos 0)
