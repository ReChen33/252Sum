# %%
print("Hello, Summer!")
# Out:
# Hello, Summer!

# %%
import numpy as np

a = np.arange(1,10,0.5)
for i, j in zip(a.to("kg m-2").value, layers):
    print(f"{i:.2f} kg m-2 in layer {j}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       3 a = np.arange(1,10,0.5)
# ----> 4 for i, j in zip(a.to("kg m-2").value, layers):
#       5     print(f"{i:.2f} kg m-2 in layer {j}")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to'
