# %%
print("Hello, Summer!")
# Out:
# Hello, Summer!

# %%
a = [1, 2, 3, 4, 5]
#let every element produce 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 a = [1, 2, 3, 4, 5]
# ----> 2 print( a+1 )
#
# TypeError: can only concatenate list (not "int") to list
